# %% [markdown]
# <a href="https://colab.research.google.com/github/ardioputra/iris_tensorflow/blob/main/iris_pred_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df = df.drop(columns='Id')

# %%
category = pd.get_dummies(df.Species)
category
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
df_new = pd.concat([df, category], axis=1)
df_new = df_new.drop(columns='Species')
df_new
# Out:
#      SepalLengthCm  SepalWidthCm  ...  Iris-versicolor  Iris-virginica
# 0              5.1           3.5  ...                0               0
# 1              4.9           3.0  ...                0               0
# 2              4.7           3.2  ...                0               0
# 3              4.6           3.1  ...                0               0
# 4              5.0           3.6  ...                0               0
# ..             ...           ...  ...              ...             ...
# 145            6.7           3.0  ...                0               1
# 146            6.3           2.5  ...                0               1
# 147            6.5           3.0  ...                0               1
# 148            6.2           3.4  ...                0               1
# 149            5.9           3.0  ...                0               1
#
# [150 rows x 7 columns]

# %%
dataset = df_new.values
dataset
# Out:
# array([[5.1, 3.5, 1.4, ..., 1. , 0. , 0. ],
#        [4.9, 3. , 1.4, ..., 1. , 0. , 0. ],
#        [4.7, 3.2, 1.3, ..., 1. , 0. , 0. ],
#        ...,
#        [6.5, 3. , 5.2, ..., 0. , 0. , 1. ],
#        [6.2, 3.4, 5.4, ..., 0. , 0. , 1. ],
#        [5.9, 3. , 5.1, ..., 0. , 0. , 1. ]])

# %%
X = dataset[:,0:4]
y = dataset[:,4:7]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
class irisCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.99):
      print('\nAkurasi mencapai >99%!')
      self.model.stop_training = True

acallbacks = irisCallback()

# %%
model = Sequential([
                    Dense(64, activation='relu', input_shape=(4,)),
                    Dense(64, activation='relu'),
                    Dense(3, activation='sigmoid')
])

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train, epochs=100, callbacks=[acallbacks])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0907 - accuracy: 0.3810
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0514 - accuracy: 0.6857
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0195 - accuracy: 0.6952
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9895 - accuracy: 0.6952
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9589 - accuracy: 0.6952
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9279 - accuracy: 0.6952
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8940 - accuracy: 0.6952
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8605 - accuracy: 0.6952
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8224 - accuracy: 0.6952
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2929 - accuracy: 0.9111
# [0.2928740680217743, 0.9111111164093018]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'],loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'],loc='lower right')
plt.show()
